# %%
import pandas as pd
import numpy as np

# %%
range_data = pd.read_csv('../../data/snp_sequence_ranges.txt', delimiter='\t')
range_data
# Out:
#          Chrom         SNP  Position     Start       End Allele1 Allele2
# 0            1   rs3131972    817341    719037    915645       G       A
# 1            1   rs3131969    818802    720498    917106       G       A
# 2            1   rs3131967    818954    720650    917258       C       T
# 3            1   rs1048488    825532    727228    923836       T       C
# 4            1  rs12562034    833068    734764    931372       A       G
# ...        ...         ...       ...       ...       ...     ...     ...
# 1034892     22   rs2285395  50739662  50641358  50818468       A       G
# 1034893     22  rs13056621  50743331  50645027  50818468       G       A
# 1034894     22   rs3888396  50772964  50674660  50818468       C       T
# 1034895     22   rs2238837  50774447  50676143  50818468       C       A
# 1034896     22  rs28729663  50780578  50682274  50818468       A       G
#
# [1034897 rows x 7 columns]

# %%
chr1_reulst = pd.read_csv('/projects/ps-renlab2/sux002/DSC180/local_testing/result/chr1_numer_1000_result.csv', delimiter='\t')

# %%
chr1_reulst = chr1_reulst.sort_values(['Result'], ascending=False)
chr1_reulst.head()
# Out:
#      Chrom         SNP  Position    Start      End Allele1 Allele2    Result
# 370      1   rs2843127   2384278  2285974  2482582       G       A  4.274983
# 568      1    rs926246   3089567  2991263  3187871       C       T  3.461670
# 478      1   rs6698817   2632744  2534440  2731048       C       T  3.319107
# 429      1   rs2246732   2518955  2420651  2617259       G       A  3.160828
# 455      1  rs10910097   2589991  2491687  2688295       T       C  3.004631

# %%
chr1_reulst['abs_result'] = abs(chr1_reulst['Result'])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(chr1_reulst['Position'], chr1_reulst['abs_result'], alpha=0.7, edgecolor='k')


plt.title('Dot Plot of SNP Positions vs. Result Values', fontsize=14)
plt.xlabel('Position (SNP)', fontsize=12)
plt.ylabel('Difference (Result)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
